# %% [markdown]
# # Самостоятельное задание №10.

# %% [markdown]
# ### Найти какое-либо изображение в сети Интернет. Создать ноутбук, в котором будет отображено выбранное изображение средствами библиотеки matplotlib по URL из сети Интернет.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
import requests

# %%
from io import BytesIO

# %%
plt.figure(figsize=(20, 20))

url = requests.get('https://sun9-3.userapi.com/impg/xHFuxvCLV2BHqaadBJxZfxWkEfSBdV6o_tBjXQ/P6OMAiBzPgk.jpg?size=807x807&quality=96&sign=58d30bb4711f37955435eb2d8528a11d&type=album')
img = Image.open(BytesIO(url.content))

plt.imshow(img)
